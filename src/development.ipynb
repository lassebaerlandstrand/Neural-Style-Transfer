# %%
import importlib
import utils
import matplotlib.pyplot as plt

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/home/ordenter/Projects/neural-style-transfer/src/utils.py'>

# %%
image = utils.load_image("data/content/landscape.jpg")

plt.imshow(image.squeeze(0).permute(1, 2, 0))
plt.show()
